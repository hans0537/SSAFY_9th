# %% [markdown]
# # 1. 논리와 증명 풀이
#
# ### 문제 1.
#
# ```
# ① ~(~p∧q)∨q
# p	q	~p	(~p∧q)	~(~p∧q)	~(~p∧q) ∨q
# T	T	F	F		T		T
# T	F	F	F		T		T
# F	T	T	T		F		T
# F	F	T	F		T		T
#
# ② (~p∨q)∨(p∧~q)
# p	q	~p	(~p∨q)	~q	(p∧~q) 	(~p∨q)∨(p∧~q)
# T	T	F	T		F	F		T
# T	F	F	F		T	T		T
# F	T	T	T		F	F		T
# F	F	T	T		T	F		T
# ```
#
# ### 문제 2.
#
# ```
# ① (~p∨q)∧(p∧~q)
# p	q	~p	(~p∨q)	~q	(p∧~q)	(~p∨q)∧(p∧~q)
# T	T	F	T		F	    F		F
# T	F	F	F		T	    T		F
# F	T	T	T		F	    F		F
# F	F	T	T		T	    F		F
#
# ② (p∧q)∧(p∧~q)
# p	q	~q	(p∧q)	(p∧~q)	(p∧q)∧(p∧~q)
# T	T	F	T	        F		F
# T	F	T	F	        T		F
# F	T	F	F	        F		F
# F	F	T	F	        F		F
# ```
#
# ### 문제 3.
#
# ```
# ① p∧(p∨q)와 p
# p	q	(p∨q)	p∧(p∨q)
# T	T	T	    T
# T	F	T	    T
# F	T	T	    F
# F	F	F	    F
#
# ② ~p∨~q와 ~(p∨q)
# ~p	~q	~p∨~q	p	q	(p∨q)	~(p∨q)
# F	F	F	    T	T	    T	    F
# F	T	T	    T	F	    T	    F
# T	F	T	    F	T	    T	    F
# T	T	T	    F	F	    F	    T
#
# ```
#
# ### 문제 4.
#
# ```
# ① (𝑝∧~𝑞)∨(𝑝∧𝑞) = 𝑝∧(~𝑞∨𝑞) = 𝑝∧𝑈= 𝑝 (이때 𝑈는 항진명제이다.)
#
# ② (𝑝∨~𝑞)∧(~𝑝∨~𝑞) = (~𝑞∨𝑝)∧(~𝑞∨~𝑝)= ~𝑞∨(𝑝∧~𝑝)= ~𝑞∨∅ = ~𝑞
#
# ```
#
# ### 문제 5.
#
# ```
# ∀ = 모든 (전체, all)
# ∃ = 어떤 (하나라도, exist)
#
# ① ∀𝑥∈𝑅,𝑥^2≥𝑥
# 𝑥=1/2일 때, 𝑥^2≥𝑥 을 만족하지 않는다. (반례)
# 따라서 ① 명제는 거짓이다.
#
# ② ∀𝑥∈𝑍,𝑥^2≥𝑥
# 해당 명제를 만족하지 않는 x의 범위는 0<𝑥<1 인데, 해당 범위엔 정수 값이 존재하지 않는다. 다시 말해 모든 정수 x에 대해 부등식 𝑥^2≥𝑥 을 만족한다고 할 수 있다. 따라서 ② 명제는 참이다.
#
# ③ ∃𝑥∈𝑅,𝑥^2<𝑥
# 𝑥=1/2일 때, 𝑥^2<𝑥 을 만족한다. (어떤 x 존재)
# 따라서 ③ 명제는 참이다.
#
# ④ ∃𝑥∈𝑍,𝑥^2<𝑥
# 𝑥^2<𝑥 , 𝑥^2−𝑥<0, 𝑥(𝑥−1)<0 이므로, 위 부등식의 해는 0<𝑥<1가 된다. 이때, 해당 부등식 조건을 만족하는 어떤 정수도 존재하지 않는다.
# 따라서 ④ 명제는 거짓이다.
# ```
#
# ### 문제 6.
#
# ```
# n = 2k 일 때, 3n + 5 = 3*(2k) + 5 = 6k + 5 = 6k + 4 + 1 = 2*(3k + 2) + 1
# 그러므로 3n + 5 는 홀수이다.
# ```
#
# ### 문제 7.
#
# ```
# n = 2k + 1 일 때, 𝑛^2+𝑛=〖(2𝑘+1)〗^2+(2𝑘+1)=4𝑘^2+4𝑘+1+2+1= 4𝑘^2+4𝑘+4=2(2𝑘^2+2𝑘+2)
# 그러므로 𝑛^2+𝑛은 짝수이다.
# ```
#
# ### 문제 8.
#
# ```
# m = 2k, n = 2l+1 일 때, 2m + 3n = 2*(2k) + 3*(2l+1) = 4k + 6l + 3 = 2(2k + 3l + 1) + 1
# 그러므로 2m+3n은 홀수이다.
# ```
#
# ### 문제 9.
#
# ```
# 명제의 대우명제는, 힌트처럼 ‘n이 홀수이면 n^2+5은 짝수이다.’와 같다.
# n = 2k + 1 일 때, n^2+5= (2k+1)^2+5= 〖4k〗^2+4k+6=2(〖2k〗^2+2k+3)
# 그러므로 n이 홀수이면 n^2+5은 짝수이다.
# 대우 명제가 참이므로, 본 명제 또한 참이다.
# ```
#
# ### 문제 10.
#
# ```
# 주어진 명제의 대우명제는, ’n이 홀수이면 n^2이 홀수이다.’와 같다.
# n = 2k + 1일 때, n^2=(2k+1)^2=〖4k〗^2+4k+1= 〖2(2k〗^2+2k)+1
# 그러므로 n이 홀수이면 n^2이 홀수이다.
# 대우 명제가 참이므로, 본 명제 또한 참이다.
# ```
#
# ### 문제 11.
#
# ```
# [n이 짝수인 경우]
# n = 2k, n^2+5n+3= (2k)^2+5(2k)+3=〖4k〗^2+10k+3=〖2(2k〗^2+5k+1)+1
# 그러므로, n이 짝수인 경우 n^2+5n+3은 항상 홀수이다.
# [n이 홀수인 경우]
# n = 2k+1, n^2+5n+3= (2k+1)^2+5(2k+1)+3=〖4k〗^2+14k+9=〖2(2k〗^2+7k+4)+1
# 그러므로, n이 홀수인 경우 n^2+5n+3은 항상 홀수이다.
# n이 짝수인 경우와 홀수인 경우 모두 n^2+5n+3은 항상 홀수이므로, 자연수 n에 대해 n^2+5n+3은 항상 홀수이다.
# ```

# %% [markdown]
# # 2. 수와 표현 풀이
#
# ### 문제 1.
#
# ```
# n비트로 표현할 수 있는 숫자는 2^n가지의 값이 있다.
# logn 비트로 표현할 수 있는 숫자는 n가지의 값이 있다.
# ```
#
# ### 문제 2.
#
# ```
# 2^20 가지
# ```
#
# ### 문제 3.
#
# ```
# ① 	2n	( <  )	  n^2
# 2<n 일 때 2n< n^2 이므로, 2보다 큰 모든 n에 대해 부등호가 항상 성립한다.
#
#
# ②	2^(n/2)	( <  )	  √(3^n )
# n>0 일 때  3^(n/2)>2^(n/2) 이 항상 성립하므로, 0보다 큰 모든 n에 대해 부등호가 항상 성립한다.
#
# ③	2^(n log⁡n )	   ( >  )    n!
# n > 1일 때, n^n>n! 이 항상 성립한다. 따라서 1보다 큰 모든 n에 대해 부등호가 항상 성립한다.
#
#
# ④	log⁡〖2^2n 〗	   (  < )    n√n
# n > 4 일 때 2n< n^(3/2) 이 항상 성립한다. 따라서 4보다 큰 모든 n에 대해 부등호가 항상 성립한다.
# ```
#
# ### 문제 4.
#
# ```
# 로그의 성질을 찾아볼 것
#
# 𝑥 = (log⁡𝑦+ log⁡𝑧)/log⁡𝑎
# ```
#
# ### 문제 5.
#
# ```
# ① 	𝑓(𝑥)=log〖(𝑥−3)〗−5
# 2^(𝑓(𝑥)+5)=𝑥−3
# 	x= 2^(𝑓(𝑥)+5)+3
# 𝑓^(−1)(𝑥)= 2^(𝑥+5)+3
#
# ②	𝑓(𝑥)=3 log〖(𝑥+3)〗+1
# 2^((𝑓(𝑥)−1)/3)=𝑥+3
# x= 2^((𝑓(𝑥)−1)/3)−3
# 𝑓^(−1)(𝑥)= 2^((𝑥−1)/3)−3
#
# ③	𝑓(𝑥)=2×3^𝑥−1
# x= log_3 (𝑓(𝑥)+1)−log_3⁡2
# 𝑓^(−1)(𝑥)=log_3 (𝑥+1)−log_3⁡2
# ```

# %% [markdown]
# # 4. 기초 수식
#
# ### 문제 1.
#
# ```
# 𝑇(𝑛)=𝑇(𝑛−1)+1
# =𝑇(𝑛−2)+1+1
# =𝑇(𝑛−𝑘)+𝑘
# =𝑇(0)+𝑘, k=n
# =1+n
# 𝑂(𝑇(𝑛))=𝑶(𝒏)
# ```
#
# ### 문제 2.
#
# ```
# 𝑇(𝑛)=𝑇(𝑛−1)+𝑛
# =𝑇(𝑛−2)+(𝑛−1)+𝑛
# =T(n-k)+(n-(k-1)) + … + n
# =T(0) + 1+… + n, n==k
#
# =1+(𝑛(𝑛+1))/2
# ∴𝑂(𝑇(𝑛))=𝑶(𝒏^𝟐 )
# ```
#
# ### 문제 3.
#
# ```
# 𝑇(𝑛)= T(0)+  log⁡𝑛+  log⁡〖(𝑛−1)〗+  log⁡〖(𝑛−2)〗+…  〖+ log〗⁡1
#     ≤ T(0)+  log⁡𝑛+  log⁡𝑛+  log⁡𝑛+…+  log⁡𝑛
#     ≤ 1+ 𝑛 log⁡𝑛
# ∴𝑇(𝑛)=𝑶(𝒏 𝐥𝐨𝐠⁡𝒏)
# ```
#
# ### 문제 4.
#
# ```
# T(n) = 1, n=1 (divide의 경우 1부터)
# 𝑇(𝑛)  =1+𝑇(𝑛/2) , n>1
# 1+1+𝑇(𝑛/2^2 )=𝑘+𝑇(𝑛/2^𝑘 )
# = k + T(1)
# 2^𝑘=𝑛 ⇒ 𝑘=log⁡𝑛
# ```
#
# ### 문제 5.
#
# ```
# T(n) = 1 , n=1
# 𝑇(𝑛)  =𝑛+𝑇(𝑛/2) , n>1
# =𝑛+(𝑛/2+𝑇(𝑛/4))
# =𝑛+  𝑛/2+𝑛/2^2 +…+𝑛/2^⁡〖𝑘−1〗  +𝑇(𝑛/2^𝑘 )
# 𝑇(𝑛/2^𝑘 )=𝑇(1)
# 2^𝑘=𝑛 ⇒ 𝑘=log⁡𝑛
#
# = n(1+1/2+…+1/2^lo𝑔(𝑛−1)) + 1 <- (1/2+1/4+1/8+… 다 더해도 1)
# = 2n + 1
#
# 혹은 등비급수로 표현
#
# ∴𝑇(𝑛)=𝑶(𝒏)
# ```
#
# ### 문제 6.
#
# ```
# 𝑇(𝑛)  =𝑛+2𝑇(𝑛/2)
# =𝑛+2(𝑛/2+2∙𝑇(𝑛/4))
# =𝑛+ 2∙𝑛/2+2^2∙𝑛/2^2 +…+2^⁡〖𝑘−1〗 ∙𝑛/2^⁡〖𝑘−1〗  +2^𝑘 𝑇(𝑛/2^𝑘 )
# T(1) => 𝑛/2^𝑘  = 1 => k = log n, 2^𝑘 = 2^𝑙𝑜𝑔𝑛 = n
#
# =nlog⁡𝑛
# ∴𝑂(𝑇(𝑛))=𝑶(𝐧𝐥𝐨𝐠⁡〖𝒏)〗
# ```
